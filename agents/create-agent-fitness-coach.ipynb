# %% [markdown]
# # Building Your First AI Agent in Microsoft Foundry
#
# In this notebook, you will learn how to build a simple AI agent from scratch using Microsoft Foundry's Agent Service. We will create a **Friendly Fitness Coach** that can help users with workout plans, exercise tips, and healthy habits.
#
# By the end of this tutorial, you will understand how to:
# - Connect to a Foundry project
# - Create an AI agent with custom instructions
# - Have a live conversation with your agent

# %% [markdown]
# ## Step 1: Install Required Packages
#
# Before we begin, we need to install the Python libraries that let us talk to Microsoft Foundry. Run the cell below to install everything you need.

# %%
# This installs all the packages we need:
# - azure-ai-projects: lets us work with Microsoft Foundry agents
# - openai: provides the chat interface for talking to agents
# - python-dotenv: loads our secret settings from a .env file
# - azure-identity: handles authentication with Azure
# %pip install azure-ai-projects==2.0.0b2 openai==1.109.1 python-dotenv azure-identity
# Out:
# Requirement already satisfied: azure-ai-projects==2.0.0b2 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (2.0.0b2)
# Requirement already satisfied: openai==1.109.1 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (1.109.1)
# Requirement already satisfied: python-dotenv in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (1.2.1)
# Requirement already satisfied: azure-identity in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (1.25.2)
# Requirement already satisfied: isodate>=0.6.1 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from azure-ai-projects==2.0.0b2) (0.7.2)
# Requirement already satisfied: azure-core>=1.35.0 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from azure-ai-projects==2.0.0b2) (1.38.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from azure-ai-projects==2.0.0b2) (4.15.0)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from azure-ai-projects==2.0.0b2) (12.28.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from openai==1.109.1) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from openai==1.109.1) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from openai==1.109.1) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from openai==1.109.1) (0.13.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from openai==1.109.1) (2.12.5)
# Requirement already satisfied: sniffio in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from openai==1.109.1) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from openai==1.109.1) (4.67.3)
# Requirement already satisfied: idna>=2.8 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai==1.109.1) (3.11)
# Requirement already satisfied: certifi in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai==1.109.1) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai==1.109.1) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.109.1) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai==1.109.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai==1.109.1) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai==1.109.1) (0.4.2)
# Requirement already satisfied: cryptography>=2.5 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from azure-identity) (46.0.5)
# Requirement already satisfied: msal>=1.31.0 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from azure-identity) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from azure-identity) (1.3.1)
# Requirement already satisfied: requests>=2.21.0 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from azure-core>=1.35.0->azure-ai-projects==2.0.0b2) (2.32.5)
# Requirement already satisfied: cffi>=2.0.0 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from cryptography>=2.5->azure-identity) (2.0.0)
# Requirement already satisfied: pycparser in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity) (3.0)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.31.0->azure-identity) (2.11.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.35.0->azure-ai-projects==2.0.0b2) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.35.0->azure-ai-projects==2.0.0b2) (2.6.3)
#
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Step 2: Connect to Your Foundry Project
#
# Here we load our configuration from a `.env` file and import the libraries we need. The `.env` file contains your Foundry project endpoint (the URL of your project) and the name of the AI model you want to use.

# %%
# Import the built-in module for reading environment variables
import os

# Import the function that reads settings from a .env file
from dotenv import load_dotenv

# Import the Azure authentication tool (uses your logged-in Azure account)
from azure.identity import DefaultAzureCredential

# Import the Foundry project client (our main connection to Foundry)
from azure.ai.projects import AIProjectClient

# Load all the key-value pairs from the .env file into environment variables
load_dotenv()

# Read the Foundry project URL from the environment
my_endpoint = os.getenv("FOUNDRY_PROJECT_ENDPOINT")

# Read the name of the AI model we want our agent to use
my_model = os.getenv("MODEL_DEPLOYMENT_NAME")

# %% [markdown]
# Now we create a **Foundry client**. Think of this as opening a connection to your Foundry project in the cloud. We pass in our endpoint URL and our Azure credentials so Foundry knows who we are.

# %%
# Create the Foundry client — this is our main gateway to the Foundry platform
# DefaultAzureCredential() automatically uses your Azure CLI login or managed identity
foundry_client = AIProjectClient(
    endpoint=my_endpoint,
    credential=DefaultAzureCredential(),
)

# %% [markdown]
# ## Step 3: Create Our Fitness Coach Agent
#
# Now for the fun part! We define our agent. An agent needs three things:
# 1. **A name** — so we can refer to it later
# 2. **A model** — the AI brain powering the agent
# 3. **Instructions** — a description of how the agent should behave
#
# We are creating a friendly fitness coach that gives workout advice and encouragement.

# %%
# Import the class that defines what kind of agent we want to build
from azure.ai.projects.models import PromptAgentDefinition

# Give our agent a unique name (this is how Foundry identifies it)
coach_agent_name = "fitness-coach"

# Create a new version of the agent in Foundry
# - model: which AI model to use for generating responses
# - instructions: tells the agent how to behave in conversations
coach_agent = foundry_client.agents.create_version(
    agent_name=coach_agent_name,
    definition=PromptAgentDefinition(
        model=my_model,
        instructions="You are a friendly and motivating fitness coach. You help people create workout plans, give exercise tips, and encourage healthy habits. Always be supportive and positive.",
    ),
)

# Print out confirmation that the agent was created successfully
print(f"Agent created (id: {coach_agent.id}, name: {coach_agent.name}, version: {coach_agent.version})")
# Out:
# Agent created (id: fitness-coach:1, name: fitness-coach, version: 1)

# %% [markdown]
# ## Step 4: Start a Conversation
#
# Before we can chat with our agent, we need two things:
# 1. **A chat client** — this is an OpenAI-compatible client that handles sending and receiving messages
# 2. **A conversation (chat session)** — this keeps track of the message history so the agent remembers what you said

# %%
# Get an OpenAI-compatible chat client from our Foundry connection
# This client knows how to send messages and receive replies
chat_client = foundry_client.get_openai_client()

# Start a brand-new conversation (like opening a fresh chat window)
# The conversation stores the full history so the agent has context
chat_session = chat_client.conversations.create()

# Show the conversation ID so we know it was created
print(f"Created conversation with id: {chat_session.id}")
# Out:
# Created conversation with id: conv_d983dc54855f992500IjPmoo8AwaA37QG04P3p1KRo30DLoaYF

# %% [markdown]
# ## Step 5: Chat with Your Agent
#
# Now we can have a back-and-forth conversation with our Fitness Coach! The loop below will:
# 1. Ask you to type a message
# 2. Send it to the agent
# 3. Print the agent's reply
# 4. Repeat until you type "exit" or "quit"
#
# Try asking things like:
# - "Can you suggest a 20-minute workout for beginners?"
# - "How many times a week should I exercise?"
# - "What are some healthy post-workout snacks?"

# %%
# This flag keeps the chat loop running — set it to False to stop
is_chatting = True

while is_chatting:
    # Wait for the user to type a message
    user_message = input("You: ")

    # If the user types "exit" or "quit", end the conversation
    if user_message.lower() in ["exit", "quit"]:
        is_chatting = False
        print("Ending the conversation. Stay active and healthy!")
    else:
        # Send the user's message to the Fitness Coach agent and get a reply
        # - conversation: links this message to our ongoing chat session
        # - extra_body: tells Foundry which agent should respond
        # - input: the actual message text from the user
        coach_reply = chat_client.responses.create(
            conversation=chat_session.id,
            extra_body={
                "agent": {
                    "name": coach_agent_name,
                    "type": "agent_reference"
                }
            },
            input=user_message
        )

        # Display the agent's response
        print(f"Coach: {coach_reply.output_text}")
# Out:
# Coach: Hey there! Looks like you’re testing the waters—ready to crush some fitness goals? Whenever you’re ready, I’m here to help you create an awesome workout plan or answer any fitness questions you have! Let’s do this! 💪😊
# Coach: Hey! Hello! 😊 Ready to get moving or have any fitness goals in mind? I’m here to help you stay motivated and make a plan that’s perfect for you! What’s on your mind today? 💪✨
# Coach: Great question! I’m here to support you every step of the way on your fitness journey. Here’s how I can help you get fit:
#
# 1. **Personalized Workout Plans:** I can create workout routines tailored to your goals, whether you want to build strength, lose weight, boost endurance, or just stay active.
#
# 2. **Exercise Tips & Demonstrations:** I’ll give you clear instructions and tips to perform exercises safely and effectively.
#
# 3. **Healthy Habits:** I can suggest nutrition tips, recovery advice, and daily habits that complement your workouts.
#
# 4. **Motivation & Encouragement:** I’ll cheer you on, celebrate your progress, and help you overcome challenges.
#
# 5. **Tracking Progress:** I can help you set achievable milestones and track improvements so you stay inspired.
#
# To get started, tell me about your current fitness level and what goals you want to work toward! 😊💪
# Coach: That’s a fantastic starting point! Walking is an excellent way to build and maintain fitness—it’s low-impact, great for your heart, and easy to fit into your day.
#
# Here’s a simple plan to build on your walking and boost your overall fitness:
#
# **1. Walking Routine:**
# - Aim for 30-45 minutes of brisk walking, 4-5 days a week.
# - Try mixing in some hills or slightly faster pace intervals to challenge yourself.
#
# **2. Strength Training (2-3 times a week):**
# - Bodyweight exercises like squats, lunges, push-ups, and planks will build strength and support your walking.
# - I can help you with easy routines for these!
#
# **3. Stretching & Mobility:**
# - Spend 5-10 minutes stretching after walking or workouts to keep muscles flexible and reduce injury risk.
#
# **4. Healthy Habits:**
# - Stay hydrated and consider a balanced diet with enough protein to support muscle recovery.
#
# Would you like me to create a weekly workout plan for you that includes walking, strength training, and flexibility work? Let me know! We’ll make it fun and doable. 😊🚶‍♂️💪
